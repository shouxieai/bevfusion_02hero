# %%
import torch
import torch.nn as nn

# %%
class Mymodel(nn.Module):
    def __init__(self):
        super().__init__()
        list1 = []
        conv2 = nn.Conv2d(1, 3, 3)
        conv3 = nn.Conv2d(3, 6, 3)
        list1.append(conv2)
        list1.append(conv3)
        self.boltnect = nn.Sequential(*list1)
        self.conv1 = nn.Conv2d(6, 1, 3)
    def forward(self, x):
        pass

# %%
model = Mymodel()
print(model)
# Out:
# Mymodel(
#   (boltnect): Sequential(
#     (0): Conv2d(1, 3, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (conv1): Conv2d(6, 1, kernel_size=(3, 3), stride=(1, 1))
# )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## BEVFusion--Swin网络
